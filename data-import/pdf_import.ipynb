# %%
import os
import pdfplumber
from pdf_import import extract_text_from_pdf, extract_text_from_txt, extract_text

# %%
text = extract_text_from_pdf("../data/ims_data _Introduction.pdf")

# %%
text
# Out:
# 'Introduction to Modern Statistics (1st Ed)\n\uf0c9\nOn this page\n1 Hello data\n1 Hello data\n1.1 Case study: Using stents to\nprevent strokes\nScientists seek to answer questions using rigorous methods and careful observations. These\n1.2 Data basics\nobservations – collected from the likes of field notes, surveys, and experiments – form the\nbackbone of a statistical investigation and are called data. Statistics is the study of how best 1.2.1 Observations, variables,\nand data matrices\nto collect, analyze, and draw conclusions from data. In this first chapter, we focus on both the\n1.2.2 Types of variables\nproperties of data and on the collection of data.\n1.2.3 Relationships between\nvariables\n1.2.4 Explanatory and response\n1.1 Case study: Using stents to prevent strokes variables\n1.2.5 Observational studies and\nIn this section we introduce a classic challenge in statistics: evaluating the efficacy of a medical experiments\ntreatment. Terms in this section, and indeed much 
# ...
